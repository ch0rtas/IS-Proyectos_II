# %% [markdown]
# # First Jupyter Notebook

# %% [markdown]
# ## Mini Markdown Cheat sheeet

# %% [markdown]
# # This is a header 1
# ## This is a header 2
# ### This is a header 3
# #### This is a header 4

# %% [markdown]
# Regular text
#
# *Italics*
#
# _Italics (another way)_
#
# **Bold**
# __Bold (another way)__
#
# **_Bold and Italics_**
# ***Bold and Italics (another way)***
#
# ~~Strikethrough~~

# %% [markdown]
# Mention functions and variables this way, `i_am_a_function()`, and code excerpts as shown below:
#
# ```python
# print('I am...')
# print('...a program program')
# ```

# %% [markdown]
# This is a [link](https://comillas.edu)

# %% [markdown]
# Ordered list:
#
# 1. item
# 2. item
#     1. subitem
#     2. subitem
# 3. item
# 4. item

# %% [markdown]
# Unordered list:
# - item
# - item
#     - subitem
#     - subitem
# - item
# - item

# %% [markdown]
# In this notebook we will start coding in **Python**. We will make use of some *features* that will be explained in later sesions. Some of those ***features*** are:
#
# * Libraries
# * Variables
# * Functions
# * Loops
#     * While
#     * For
#         - Type 1
#         - Type 2

# %% [markdown]
# An image:
#
# ![Image](pythonlogo.jpg)
#
# we can include a path if required:
#
# (../images/anatomy.svg)

# %% [markdown]
# A table:
#
# | Taxable income     | Rate (%)     |
# | :----------------- | :----------- |
# | First 5.000 euros  | 0%           |
# | Next 30.000 euros  | 10%          |
# | Next 65.000 euros  | 20%          |
# | Remaining          | 33%          |

# %% [markdown]
# And also $\LaTeX$, which can be rendered inline $E=mc^2$ or this other way:
#
# $$
# \sigma^2 = \frac{1}{N-1} \sum_{i=1}^{N} \left( {x_i - \bar{x}} \right)^2
# $$

# %% [markdown]
# # Exercise

# %% [markdown]
# ## Understanding how to include line breaks
# ### subtitle 1
# #### subtitle 2

# %% [markdown]
# How can I include line breaks? Including 2 or mores spaces at the end of the sentence
# frase 1
# frase 2
# frase 3
#
# frase 1
# frase 2
# frase 3
#
# This is one line that is ended with less that one space
# So this one is just printed together
#
# Now I will end this line with two or more spaces
# This is translated into a new line

# %% [markdown]
# ## Links, Lines and code
#
# <!-- [Text](link) -->
# [Comillas University](https://www.comillas.edu "Optional Title")
#
#
# ## New section (with a line below)
#
# ---
# yes!!!
#
#
# ## Remember how to codify hello world in python:
# > print("Hello World")

# %% [markdown]
# # Using Latex to include formulas

# %% [markdown]
# $$f(x) = \sqrt[2]{x^4 + x^3+ x^2 + x^1 + 1} $$
#
# $f(x) = \sqrt[2]{x^4 + x^3+ x^2 + x^1 + 1} $
#
#
# $$f_1(x)=\frac{\log{(x^4+x^3+x^2+x+1)}}{\log{x^4}}$$

# %% [markdown]
# Given : $\pi = 3.14$ , $\alpha = \frac{3\pi}{4}\, rad$
# $$
# \omega = 2\pi f \\
# f = \frac{c}{\lambda}\\
# \lambda_0=\theta^2+\delta\\
# \Delta\lambda = \frac{1}{\lambda^2}
# $$

# %% [markdown]
# <https://towardsdatascience.com/write-markdown-latex-in-the-jupyter-notebook-10985edb91fdX>
